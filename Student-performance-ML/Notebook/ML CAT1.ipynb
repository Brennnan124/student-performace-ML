# %%
pip install pandas scikit-learn matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.chdir(r'C:\Users\brenn_nq6ofsd\OneDrive\Desktop\Student-performance-ML')

# %% [markdown]
# Question 1;

# %% [markdown]
# load the dataset

# %%
import pandas as pd

df = pd.read_csv('data/student-por.csv', sep=';')

df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# *Check for missing values*

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# **Encode categoricals**

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded['pass'] = (df['G3'] >= 10).astype(int)

# %% [markdown]
# **Create Target Variables**

# %%
df_encoded.drop(['G1', 'G2', 'G3'], axis=1, inplace=True)

# %% [markdown]
# **Task 2 Feature selection/engineering and data splitting**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_encoded.drop('pass', axis=1)
y = df_encoded['pass']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Step 3  Model training using at least two machine learning algorithms**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# *Logistic regression*

# %%
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# *Decision Tree*

# %%
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# *Random Forest*

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# **Task 4; Evaluate the models**

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %% [markdown]
# *Logistic Regression Results*

# %%
y_pred_log = log_model.predict(X_test)

print("=== Logistic Regression Results ===")
print("Accuracy:", accuracy_score(y_test, y_pred_log))
print("F1 Score:", f1_score(y_test, y_pred_log))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_log))
# Out:
# === Logistic Regression Results ===
# Accuracy: 0.882051282051282
# F1 Score: 0.9340974212034384
# Confusion Matrix:
#  [[  9  17]
#  [  6 163]]

# %% [markdown]
# *Decision Tree Results*

# %%
y_pred_tree = tree_model.predict(X_test)

print("\n=== Decision Tree Results ===")
print("Accuracy:", accuracy_score(y_test, y_pred_tree))
print("F1 Score:", f1_score(y_test, y_pred_tree))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_tree))
# Out:
# === Decision Tree Results ===
# Accuracy: 0.8256410256410256
# F1 Score: 0.8975903614457831
# Confusion Matrix:
#  [[ 12  14]
#  [ 20 149]]

# %% [markdown]
# *Random Forest Results*

# %%
y_pred_rf = rf.predict(X_test)

print("\n=== Random Forest Results ===")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("F1 Score:", f1_score(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# === Random Forest Results ===
# Accuracy: 0.8717948717948718
# F1 Score: 0.9303621169916435
# Confusion Matrix:
#  [[  3  23]
#  [  2 167]]

# %% [markdown]
# *Results of the 3 models*

# %%
results = {
    'Model': ['Logistic Regression', 'Decision Tree', 'Random Forest'],
    'Accuracy': [
        accuracy_score(y_test, y_pred_log),
        accuracy_score(y_test, y_pred_tree),
        accuracy_score(y_test, y_pred_rf)
    ],
    'F1 Score': [
        f1_score(y_test, y_pred_log),
        f1_score(y_test, y_pred_tree),
        f1_score(y_test, y_pred_rf)
    ]
}

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                  Model  Accuracy  F1 Score
# 0  Logistic Regression  0.882051  0.934097
# 1        Decision Tree  0.825641  0.897590
# 2        Random Forest  0.871795  0.930362

# %%
import os
os.chdir(r'C:\Users\brenn_nq6ofsd\OneDrive\Desktop\Student-performance-ML')
